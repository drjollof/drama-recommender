# %%
import pandas as pd 
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import re
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('asianmovies.csv')

# %%
df.tail()
# Out:
#       Unnamed: 0                                             titles  \
# 4965        4965                            The Furthest End Awaits
# 4966        4966                                      Contact Point
# 4967        4967  Isao Takahata and His Tale of the Princess Kaguya
# 4968        4968                                   Beautiful Legacy
# 4969        4969                                      Orpheus' Lyre
#
#                                                   links  user_rating  \
# 4965  https://mydramalist.com/8185-the-furthest-end-...          7.5
# 4966       https://mydramalist.com/753259-contact-point          7.4
# 4967  https://mydramalist.com/728987-isao-takahata-a...          7.5
# 4968      https://mydramalist.com/7864-beautiful-legacy          7.5
# 4969          https://mydramalist.com/6958-orpheus-lyre          7.5
#
#              country  year screenwriter  \
# 4965  Japanese Movie  2015          NaN
# 4966    Korean Movie  2014          NaN
# 4967  Japanese Movie  2015          NaN
# 4968    Korean Movie  2011          NaN
# 4969  Japanese Movie  2013          NaN
#
#                                     director  \
# 4965                                   Drama
# 4966                    Web Movie,Short Film
# 4967                                     NaN
# 4968                                     NaN
# 4969  Attempted Suicide,Adapted From A Novel
#
#                                             description  \
# 4965  Misaki Yoshida runs a roasting coffee shop in ...
# 4966  Sun Woo receives a call from his ex-girlfriend...
# 4967  For his first film in fourteen years animation...
# 4968  Father is dead!\nSoo Jeong, Min Seong, and Kye...
# 4969  Yoko  lost her young daughter Kanako through a...
#
#                                         tags  \
# 4965                                     NaN
# 4966                    Web Movie,Short Film
# 4967                                     NaN
# 4968                                     NaN
# 4969  Attempted Suicide,Adapted From A Novel
#
#                                                    cast  \
# 4965  Sasaki Nozomi,Nagasaku Hiromi,Sakurada Hiyori,...
# 4966                            Son Suk Ku,Choi Hee Seo
# 4967  Miyazaki Hayao,Asakura Aki,Chii Takeo,Miyamoto...
# 4968  Kim Min Soo,Jeon Moo Song,Lim Hyun Sung,Dong H...
# 4969  Fukuda Mayuko,Inagaki Goro,Hirosue Ryoko,Enami...
#
#                        genres user_count content_rating
# 4965                    Drama         38              G
# 4966            Romance,Drama         12             NR
# 4967              Documentary         15             NR
# 4968  Romance,Drama,Melodrama          8             NR
# 4969                    Drama         12             NR

# %%
#df.query('year == 2023 and country == "Japanese Movie "')

# %%
del df['Unnamed: 0']
df['titles'] = df['titles'].str.strip()
df['titles'] = df['titles'].str.lower()

# %%
description = df['description'].to_list()

# %%
def clean_description(text):
    text = re.sub(r'\n+', ' ', text)  # Replace multiple newlines with a space
    text = re.sub(r'\(Source:.*?\)', '', text)  # Remove "(Source: ...)"
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces  
    text = text.split("~~")[0].strip()
    text = text.replace('Edit Translation', '') 
    text = text.replace('\"', '')
    return text

# %%
cleaned = [clean_description(i) for i in description]
cleaned_series = pd.Series(cleaned)
df['description'] = cleaned_series

# %%
df[df['director'] == df['tags']]
# Out:
#                                 titles  \
# 51                 legend of bruce lee
# 54                          pink dream
# 57    mishima: a life in four chapters
# 89     the adventures of milo and otis
# 94        violent panic: the big crash
# ...                                ...
# 4947                          fighting
# 4950                     cats and dogs
# 4953                           my 1876
# 4966                     contact point
# 4969                     orpheus' lyre
#
#                                                   links  user_rating  \
# 51    https://mydramalist.com/73047-legend-of-bruce-lee          8.9
# 54            https://mydramalist.com/752271-pink-dream          8.4
# 57    https://mydramalist.com/771323-mishima-a-life-...          8.1
# 89    https://mydramalist.com/20650-the-adventures-o...          8.0
# 94    https://mydramalist.com/708745-violent-panic-t...          8.0
# ...                                                 ...          ...
# 4947              https://mydramalist.com/9636-fighting          7.5
# 4950        https://mydramalist.com/14040-cats-and-dogs          7.5
# 4953              https://mydramalist.com/59007-my-1876          7.5
# 4966       https://mydramalist.com/753259-contact-point          7.4
# 4969          https://mydramalist.com/6958-orpheus-lyre          7.5
#
#                country  year screenwriter  \
# 51    Hong Kong Movie   1976          NaN
# 54      Chinese Movie   1932          NaN
# 57     Japanese Movie   1985          NaN
# 89     Japanese Movie   1986          NaN
# 94     Japanese Movie   1976          NaN
# ...                ...   ...          ...
# 4947     Chinese Movie  2014          NaN
# 4950      Korean Movie  2013          NaN
# 4953     Chinese Movie  2013          NaN
# 4966      Korean Movie  2014          NaN
# 4969    Japanese Movie  2013          NaN
#
#                                                director  \
# 51                     Inspired By A True Story,Kung Fu
# 54    Writer Male Lead,Silent Film,Black And White,I...
# 57    Nationalism,Co-produced,Art House Film,Patriot...
# 89                            Cat,Dog,Animal,Friendship
# 94                  Robber Male Lead,Robbery,Heist,Gang
# ...                                                 ...
# 4947                         Athlete Male Lead,Suspense
# 4950                                     Dog,Cat,Animal
# 4953                                         Short Film
# 4966                               Web Movie,Short Film
# 4969             Attempted Suicide,Adapted From A Novel
#
#                                             description  \
# 51    Bruce Li stars in this Bruce Lee biopic, very ...
# 54    Young novelist who is supported by a loving an...
# 57    A fictional account of the life of Japanese au...
# 89    The adventures of a young cat and a dog as the...
# 94    Takashi, a bank robber, dreams of his final he...
# ...                                                 ...
# 4947  The film centres around a gifted young athlete...
# 4950  A dog-like guy keeping a cat, a cat-like girl ...
# 4953
# 4966  Sun Woo receives a call from his ex-girlfriend...
# 4969  Yoko lost her young daughter Kanako through an...
#
#                                                    tags  \
# 51                     Inspired By A True Story,Kung Fu
# 54    Writer Male Lead,Silent Film,Black And White,I...
# 57    Nationalism,Co-produced,Art House Film,Patriot...
# 89                            Cat,Dog,Animal,Friendship
# 94                  Robber Male Lead,Robbery,Heist,Gang
# ...                                                 ...
# 4947                         Athlete Male Lead,Suspense
# 4950                                     Dog,Cat,Animal
# 4953                                         Short Film
# 4966                               Web Movie,Short Film
# 4969             Attempted Suicide,Adapted From A Novel
#
#                                                    cast  \
# 51    Bruce Li,Ko Hsiao Pao,Lung Fei,Wei Ping Ao,Sha...
# 54                                Tam Ying,Zheng Jun Li
# 57    Ogata Ken,Hirata Mitsuru,Nagashima Toshiyuki,M...
# 89                 Tanikawa Shuntaro,Sakaguchi Takeharu
# 94    Watase Tsunehiko,Sugimoto Miki,Watanabe Yayoi,...
# ...                                                 ...
# 4947   Peter Ho,Lu Yi,Wu Ma,Zhang Xiao Jun,Wei Yi,Qi Ke
# 4950             Son Min Ji,Shin Myung Geun,Baek Jae Ho
# 4953                       Feng Shao Feng,Gao Yuan Yuan
# 4966                            Son Suk Ku,Choi Hee Seo
# 4969  Fukuda Mayuko,Inagaki Goro,Hirosue Ryoko,Enami...
#
#                               genres user_count content_rating
# 51         Action,Drama,Martial Arts          3             NR
# 54          Historical,Romance,Drama          3             NR
# 57        Historical,Drama,Political         10              R
# 89            Adventure,Drama,Family         24             NR
# 94                      Action,Crime          3             NR
# ...                              ...        ...            ...
# 4947         Action,Thriller,Fantasy         15             NR
# 4950  Comedy,Romance,Drama,Melodrama          3             NR
# 4953                   Romance,Drama          3             NR
# 4966                   Romance,Drama         12             NR
# 4969                           Drama         12             NR
#
# [566 rows x 13 columns]

# %%
df.query('director == genres')

# %%
reversed = pd.Series(df.index, index= df['titles'])

# %% [markdown]
# #### MOVIE RECOMMENDATION BY TAGS

# %%
df['tags'].fillna(df['genres'])
# Out:
# 0       Animal,Dog,Based On A True Story,Professor Mal...
# 1       Village Setting,Samurai Male Lead,Male Centere...
# 2       Samurai Male Lead,Bushido,Japanese New Wave,Hi...
# 3       Terminal Illness,Bureaucracy,Social Commentary...
# 4       Father-Son Relationship,Mental Illness,Power S...
#                               ...
# 4965                                                Drama
# 4966                                 Web Movie,Short Film
# 4967                                          Documentary
# 4968                              Romance,Drama,Melodrama
# 4969               Attempted Suicide,Adapted From A Novel
# Name: tags, Length: 4970, dtype: object

# %%
tags = df['tags']

# %%
tags_na_removed = df['tags'].dropna(ignore_index=True)

# %%
tags = tags.fillna('No tags')

# %%
tags = tags.str.replace(' ', '')
tags = tags.str.lower()

# %%
cv = CountVectorizer()
transformed_tags = cv.fit_transform(tags)
sim = cosine_similarity(transformed_tags, transformed_tags)

# %%
transformed_tags.shape
# Out:
# (4970, 2784)

# %%
def get_recommendation_bytag(title, sim = sim):
    idx = reversed[title]
    cos_score = list(enumerate(sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
get_recommendation_bytag('lighting up the stars')
# Out:
#                                   titles  similarity
# 0                  lighting up the stars    1.000000
# 1                                   papa    0.596285
# 2                          salut d'amour    0.596285
# 3                           dad for rent    0.596285
# 4                      moratorium tamako    0.547723
# 5                                   step    0.527046
# 6                    an autumn afternoon    0.516398
# 7             sori: voice from the heart    0.516398
# 8                          oi handsome!!    0.516398
# 9                      a day with my son    0.516398
# 10                             a bedsore    0.489898
# 11                         still walking    0.484544
# 12                   christmas in august    0.456435
# 13             my dad is a heel wrestler    0.447214
# 14                         gunkan shonen    0.447214
# 15                  the shadowless tower    0.447214
# 16                        meet mr. daddy    0.447214
# 17  how the lack of love affects two men    0.447214
# 18                               to live    0.440386
# 19                       seoul searching    0.438357

# %%
get_recommendation_bytag('lighting up the stars')
# Out:
#                                   titles  similarity
# 0                  lighting up the stars    1.000000
# 1                                   papa    0.596285
# 2                          salut d'amour    0.596285
# 3                           dad for rent    0.596285
# 4                      moratorium tamako    0.547723
# 5                                   step    0.527046
# 6                    an autumn afternoon    0.516398
# 7             sori: voice from the heart    0.516398
# 8                          oi handsome!!    0.516398
# 9                      a day with my son    0.516398
# 10                             a bedsore    0.489898
# 11                         still walking    0.484544
# 12                   christmas in august    0.456435
# 13             my dad is a heel wrestler    0.447214
# 14                         gunkan shonen    0.447214
# 15                  the shadowless tower    0.447214
# 16                        meet mr. daddy    0.447214
# 17  how the lack of love affects two men    0.447214
# 18                               to live    0.440386
# 19                       seoul searching    0.438357

# %% [markdown]
# #### RECOMMENDATION USING MOVIE DESCRIPTION

# %%
tv = CountVectorizer(stop_words= 'english')
transformed = tv.fit_transform(cleaned_series)
cos = cosine_similarity(transformed, transformed)

# %%
tv = TfidfVectorizer(stop_words='english')
transformed = tv.fit_transform(cleaned_series)
cos = linear_kernel(transformed, transformed)

# %%
CountVectorizer()
# Out:
# CountVectorizer()

# %%
transformed.shape
# Out:
# (4970, 21713)

# %%
reversed[reversed== 2709]
# Out:
# titles
# monster    2709
# dtype: int64

# %%
#idx = reversed[title]
cos_score = list(enumerate(cos[2709]))
cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
first_10 = cos_score[0:10]
rec_indices = [x[0] for x in first_10]
rec_sim = [x[1] for x in first_10]
soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
hot = pd.Series(rec_sim).to_frame()
dff = pd.concat((soft, hot), axis= 1)
dff.columns=['titles', 'similarity']
dff
# Out:
#                  titles  similarity
# 0               monster    1.000000
# 1              silenced    0.226271
# 2  shichinin no tomurai    0.170784
# 3             lost love    0.152134
# 4      school excursion    0.143379
# 5    sansho the bailiff    0.140129
# 6               at home    0.134022
# 7          tokyo family    0.129332
# 8        kuchisake onna    0.117565
# 9         birthday card    0.116847

# %%
def get_recommendation(title, cos =  cos):
    idx = reversed[title]
    cos_score = list(enumerate(cos[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
get_recommendation('confidential assignment')
# Out:
#                                       titles  similarity
# 0                    confidential assignment    1.000000
# 1                        joint security area    0.307776
# 2   confidential assignment 2: international    0.272549
# 3                                 steel rain    0.258217
# 4                                       6/45    0.254622
# 5                                    the net    0.239689
# 6                    children gone to poland    0.233145
# 7                                   poongsan    0.224492
# 8                             secret reunion    0.222408
# 9                             beautiful days    0.220903
# 10                                   veteran    0.218855
# 11                         the long way home    0.218801
# 12                        the spy gone north    0.214668
# 13                           hello, stranger    0.201801
# 14                           ordinary people    0.199653
# 15                           city of fathers    0.188113
# 16                            dear pyongyang    0.170360
# 17        tae guk gi: the brotherhood of war    0.169535
# 18                        i, the executioner    0.169251
# 19                          romantic debtors    0.168742

# %%
get_recommendation_bytag('confidential assignment')
# Out:
#                                         titles  similarity
# 0                      confidential assignment    1.000000
# 1     confidential assignment 2: international    0.600000
# 2                             secretly greatly    0.400000
# 3                                       carter    0.381385
# 4                           operation chromite    0.300000
# 5                                   the prison    0.300000
# 6          the gangster, the cop and the devil    0.300000
# 7        the accidental detective 2: in action    0.300000
# 8       dragon inn part 1: the city of sadness    0.300000
# 9                             masquerade night    0.300000
# 10                                  believer 2    0.300000
# 11                        confession of murder    0.300000
# 12                         rumble in the bronx    0.286039
# 13                                  steel rain    0.286039
# 14                                 hard boiled    0.282843
# 15                                mr. nice guy    0.282843
# 16                         the classified file    0.282843
# 17                                   the scent    0.282843
# 18                                  fierce cop    0.258199
# 19  the city that never sleeps: shinjuku shark    0.239046

# %%
get_recommendation('exhuma')
# Out:
#                                                titles  similarity
# 0                                              exhuma    1.000000
# 1                                       the concubine    0.180253
# 2                                     rules of dating    0.173399
# 3                                     a frozen flower    0.144851
# 4                                hwayi: a monster boy    0.143215
# 5                                   citizen of a kind    0.139662
# 6                                       dancing queen    0.139147
# 7                                          man wanted    0.133890
# 8                                      perfect number    0.128801
# 9             along with the gods 2: the last 49 days    0.127768
# 10                                south of the border    0.125744
# 11                                             jigoku    0.120599
# 12                                   begging for love    0.117997
# 13                                five senses of eros    0.115314
# 14                                   don't cry, mommy    0.111036
# 15                                 when i turned nine    0.107395
# 16                               fantasy of the girls    0.103663
# 17                                         first kiss    0.103142
# 18                                      hello my love    0.100136
# 19  kaizoku sentai goukaiger vs. space sheriff gav...    0.098979

# %%
get_recommendation_bytag('exhuma')
# Out:
#                                       titles  similarity
# 0                                     exhuma    1.000000
# 1                dr. cheon and lost talisman    0.381385
# 2                            karaoke crazies    0.316228
# 3                            qin zei you dao    0.316228
# 4                            address unknown    0.316228
# 5             the secret of the black dahlia    0.316228
# 6            jenius: countdown in the riddle    0.316228
# 7               monster emperor: extra story    0.316228
# 8                the cursed: dead man's prey    0.316228
# 9                    while you were sleeping    0.316228
# 10  bayside shakedown 3: set the guys loose!    0.316228
# 11                           the missing gun    0.316228
# 12                        love and treachery    0.316228
# 13                                     trunk    0.316228
# 14                            love in summer    0.316228
# 15                                 onmyoji 0    0.282843
# 16               trick the movie: last stage    0.239046
# 17                     the butterfly murders    0.223607
# 18        the adventures of kosuke kindaichi    0.223607
# 19                                   bad cop    0.223607

# %%
get_recommendation_bycast('exhuma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_recommendation_bycast('exhuma')
#
# NameError: name 'get_recommendation_bycast' is not defined

# %%
get_recommendation_bygenre('exhuma')
# Out:
#                                   titles  similarity
# 0   whispering corridors 2: memento mori         1.0
# 1                   whispering corridors         1.0
# 2                            the wailing         1.0
# 3               house of the disappeared         1.0
# 4                              the mimic         1.0
# 5                    hide and never seek         1.0
# 6                gonjiam: haunted asylum         1.0
# 7                             the closet         1.0
# 8                svaha: the sixth finger         1.0
# 9                                deja vu         1.0
# 10           the cursed: dead man's prey         1.0
# 11                             re/member         1.0
# 12                 the grotesque mansion         1.0
# 13                         the 8th night         1.0
# 14                       rohan au louvre         1.0
# 15                        the haunting 2         1.0
# 16                        the haunting 3         1.0
# 17                                exhuma         1.0
# 18                 a tale of two sisters         1.0
# 19                               the eye         1.0

# %% [markdown]
# ##### MOVIE RECOMMENDATION BY CAST

# %%
cast = df['cast']

# %%
cast = cast.fillna('nocast')

# %%
cast = cast.str.strip()
cast = cast.str.replace(' ', '')
cast = cast.str.lower()

# %%
cs = CountVectorizer()
cast_transformed  = cs.fit_transform(cast)
cast_sim = cosine_similarity(cast_transformed, cast_transformed)

# %%
def get_recommendation_bycast(title, cast_sim = cast_sim):
    idx = reversed[title]
    cos_score = list(enumerate(cast_sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
genre =  df['genres']

# %%
genre = genre.fillna('no genre')
genre = genre.str.strip()
genre = genre.str.replace(' ', '')
genre = genre.str.lower()

# %%
gn = TfidfVectorizer()
genre_transformed = gn.fit_transform(genre)
genre_sim = linear_kernel(genre_transformed, genre_transformed)

# %%
def get_recommendation_bygenre(title, genre_sim = genre_sim):
    idx = reversed[title]
    cos_score = list(enumerate(genre_sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
pd.DataFrame(cos, index=df["titles"], columns=df["titles"])

# %%
combined = (genre + ','  + tags)

# %%
comb = CountVectorizer()
combined_transformed = comb.fit_transform(combined)
comb_sim = cosine_similarity(combined_transformed, combined_transformed)

# %%
def get_recommendation_bycombination(title, comb_sim = comb_sim):
    idx = reversed[title]
    cos_score = list(enumerate(comb_sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    rec = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    year = pd.Series(list(df['year'].iloc[rec_indices])).to_frame()
    country = pd.Series(list(df['country'].iloc[rec_indices])).to_frame()
    sim = pd.Series(rec_sim).to_frame()
    dff = pd.concat((rec, year, country, sim), axis= 1)
    dff.columns=['titles', 'year', 'country','similarity']
    return dff

# %%
get_recommendation_bycombination('exhuma')
# Out:
#                           titles  year          country  similarity
# 0                         exhuma  2024     Korean Movie    1.000000
# 1    the cursed: dead man's prey  2021    Korean Movie     0.358569
# 2                    satoru dayo  2015   Japanese Movie    0.310087
# 3                    the wailing  2016    Korean Movie     0.300000
# 4                      the mimic  2017    Korean Movie     0.300000
# 5                 the haunting 3  2023   Chinese Movie     0.298807
# 6                      possessed  2009     Korean Movie    0.292770
# 7                     cinderella  2006     Korean Movie    0.292770
# 8                         spiral  1998  Japanese Movie     0.288675
# 9                oppressive love  2016   Chinese Movie     0.288675
# 10               rohan au louvre  2023  Japanese Movie     0.279508
# 11                    bilocation  2014   Japanese Movie    0.279508
# 12  leaping over the dragon gate  2021   Chinese Movie     0.273861
# 13                the haunting 2  2023   Chinese Movie     0.271163
# 14     spec: close - incarnation  2013   Japanese Movie    0.269680
# 15                   the complex  2013   Japanese Movie    0.269680
# 16                         sleep  2023    Korean Movie     0.263523
# 17  folk stories: the tricksters  2023   Chinese Movie     0.258199
# 18                         tarot  2024     Korean Movie    0.258199
# 19                         trunk  2013     Korean Movie    0.258199

# %%
get_recommendation_bycombination('')
# Out:
#                                     titles  year           country  similarity
# 0                          rurouni kenshin  2012    Japanese Movie    1.000000
# 1         rurouni kenshin: the legend ends  2014    Japanese Movie    0.733333
# 2           rurouni kenshin: kyoto inferno  2014    Japanese Movie    0.733333
# 3               rurouni kenshin: the final  2021   Japanese Movie     0.600000
# 4                  have sword, will travel  1969  Hong Kong Movie     0.577350
# 5                                    azumi  2003    Japanese Movie    0.544949
# 6           rurouni kenshin: the beginning  2021   Japanese Movie     0.533333
# 7                       the blood brothers  1973  Hong Kong Movie     0.527046
# 8                   azumi 2: death or love  2005    Japanese Movie    0.527046
# 9                               11 samurai  1967   Japanese Movie     0.516398
# 10                            13 assassins  1963   Japanese Movie     0.516398
# 11                        the rise of hero  2019    Chinese Movie     0.516398
# 12             the 36th chamber of shaolin  1978  Hong Kong Movie     0.489898
# 13                    three outlaw samurai  1964   Japanese Movie     0.489898
# 14  zatoichi meets the one-armed swordsman  1971   Japanese Movie     0.487950
# 15                                   sakra  2023  Hong Kong Movie     0.487950
# 16                          touken ranbu 2  2023   Japanese Movie     0.487950
# 17                     the masked avengers  1982  Hong Kong Movie     0.467099
# 18                                  goemon  2009    Japanese Movie    0.466667
# 19                  incident at blood pass  1970   Japanese Movie     0.461880
