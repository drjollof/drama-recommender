# %%
import pandas as pd 
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import re
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('asianmovies.csv')

# %%
df.tail()

# %%
df.query('year == 2023 and country == "Japanese Movie "')
# Out:
#                                        titles  \
# 2709                                  monster
# 2711                       godzilla minus one
# 2713            as long as we both shall live
# 2716                         our secret diary
# 2718                             perfect days
# ...                                       ...
# 2942                                    kyrie
# 2945                           one last bloom
# 2947                ichikei's crow: the movie
# 2950                            jigen daisuke
# 2959  tonde saitama: biwako yori ai wo komete
#
#                                                   links  user_rating  \
# 2709            https://mydramalist.com/743747-kaibutsu          9.0
# 2711  https://mydramalist.com/755475-godzilla-minus-one          8.5
# 2713   https://mydramalist.com/726653-my-happy-marriage          8.5
# 2716    https://mydramalist.com/748899-our-secret-diary          8.4
# 2718        https://mydramalist.com/752603-perfect-days          8.3
# ...                                                 ...          ...
# 2942        https://mydramalist.com/751205-kyrie-no-uta          7.5
# 2945       https://mydramalist.com/740065-haru-ni-chiru          7.5
# 2947  https://mydramalist.com/732779-ichikei-s-crow-...          7.5
# 2950       https://mydramalist.com/758539-jigen-daisuke          7.5
# 2959     https://mydramalist.com/708075-tonde-saitama-2          7.5
#
#               country  year  \
# 2709  Japanese Movie   2023
# 2711  Japanese Movie   2023
# 2713  Japanese Movie   2023
# 2716  Japanese Movie   2023
# 2718  Japanese Movie   2023
# ...               ...   ...
# 2942  Japanese Movie   2023
# 2945  Japanese Movie   2023
# 2947  Japanese Movie   2023
# 2950  Japanese Movie   2023
# 2959  Japanese Movie   2023
#
#                                            screenwriter          director  \
# 2709                              Thriller,Drama,Family  Koreeda Hirokazu
# 2711                     Action,Tokusatsu,Horror,Sci-Fi  Yamazaki Takashi
# 2713                   Historical,Romance,Drama,Fantasy       Kanno Tomoe
# 2716                                      Romance,Youth  Takemura Kentaro
# 2718  Cleaner Male Lead,Loner Male Lead,Co-produced,...        Life,Drama
# ...                                                 ...               ...
# 2942                                  Music,Youth,Drama       Iwai Shunji
# 2945  Boxer Male Lead,Athlete Male Lead,Boxing,Adapt...      Drama,Sports
# 2947                                      Hamada Hideya        Tanaka Ryo
# 2950                     Action,Adventure,Mystery,Drama  Hashimoto Hajime
# 2959                                    Tokunaga Yuichi   Takeuchi Hideki
#
#                                             description  \
# 2709  A suburban town with a large lake. A single mo...
# 2711  Post-war Japan is at its lowest point when a n...
# 2713  Saimori Miyo, the daughter of a loveless marri...
# 2716  Nozomi, a second-year high schooler, finds a l...
# 2718  Hirayama works as a toilet cleaner in Tokyo. H...
# ...                                                 ...
# 2942  In the Great East Japan Earthquake, a young gi...
# 2945  Hirooka Jinichi is a former boxer. He lost a b...
# 2947  Two years after Iruma Michio left first crimin...
# 2950  Feeling unhappy with his gun, Jigen is looking...
# 2959  People of Saitama Prefecture, who have been pe...
#
#                                                    tags  \
# 2709  School Bullying,Coming Of Age,Mother-Son Relat...
# 2711  Pilot Male Lead,Post World War 2,Kamikaze,Kaij...
# 2713  Arranged Marriage,Supernatural Power,Supernatu...
# 2716  School Setting,Popular Male Lead,High School,M...
# 2718  Cleaner Male Lead,Loner Male Lead,Co-produced,...
# ...                                                 ...
# 2942          Musician Female Lead,Adapted From A Novel
# 2945  Boxer Male Lead,Athlete Male Lead,Boxing,Adapt...
# 2947  Criminal Justice System,Courtroom Setting,Judg...
# 2950       Web Movie,Adapted From A Manga,Investigation
# 2959                               Adapted From A Manga
#
#                                                    cast  \
# 2709  Ando Sakura,Nagayama Eita,Kurokawa Souya,Hiira...
# 2711  Kamiki Ryunosuke,Hamabe Minami,Yamada Yuki,Aok...
# 2713  Imada Mio,Meguro Ren,Watanabe Keisuke,Onishi R...
# 2716  Takahashi Fumiya,Sakurada Hiyori,Kayashima Miz...
# 2718  Yakusho Koji,Emoto Tokio,Aoi Yamada,Aso Yumi,I...
# ...                                                 ...
# 2942  Aina The End,Matsumura Hokuto,Kuroki Haru,Hiro...
# 2945  Sato Koichi,Yokohama Ryusei,Yamaguchi Tomoko,H...
# 2947  Takenouchi Yutaka,Kuroki Haru,Mukai Osamu,Sait...
# 2950  Tamayama Tetsuji,Maki Kotoka,Maki Yoko,Nagase ...
# 2959  GACKT,Nikaido Fumi,Watanabe Anne,Kataoka Ainos...
#
#                                 genres user_count content_rating
# 2709             Thriller,Drama,Family      6,862              G
# 2711    Action,Tokusatsu,Horror,Sci-Fi      2,542              G
# 2713  Historical,Romance,Drama,Fantasy     11,137              G
# 2716                     Romance,Youth      9,142              G
# 2718                        Life,Drama      1,151             NR
# ...                                ...        ...            ...
# 2942                 Music,Youth,Drama         71              G
# 2945                      Drama,Sports         26              G
# 2947          Mystery,Comedy,Law,Drama         43              G
# 2950    Action,Adventure,Mystery,Drama         95            15+
# 2959                         Adventure         18             NR
#
# [85 rows x 13 columns]

# %%
del df['Unnamed: 0']
df['titles'] = df['titles'].str.strip()
df['titles'] = df['titles'].str.lower()

# %%
description = df['description'].to_list()

# %%
def clean_description(text):
    text = re.sub(r'\n+', ' ', text)  # Replace multiple newlines with a space
    text = re.sub(r'\(Source:.*?\)', '', text)  # Remove "(Source: ...)"
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces  
    text = text.split("~~")[0].strip()
    text = text.replace('Edit Translation', '') 
    text = text.replace('\"', '')
    return text

# %%
cleaned = [clean_description(i) for i in description]
cleaned_series = pd.Series(cleaned)
df['description'] = cleaned_series

# %%
df[df['director'] == df['tags']]

# %%
df.query('director == genres')

# %% [markdown]
# #### MOVIE RECOMMENDATION BY TAGS

# %%
df['tags'].fillna(df['genres'])

# %%
tags = df['tags']

# %%
tags_na_removed = df['tags'].dropna(ignore_index=True)

# %%
tags = tags.fillna('No tags')

# %%
tags = tags.str.replace(' ', '')
tags = tags.str.lower()

# %%
cv = CountVectorizer()
transformed_tags = cv.fit_transform(tags)
sim = cosine_similarity(transformed_tags, transformed_tags)

# %%
transformed_tags.shape
# Out:
# (4970, 2784)

# %%
def get_recommendation_bytag(title, sim = sim):
    idx = reversed[title]
    cos_score = list(enumerate(sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
get_recommendation_bytag('lighting up the stars')
# Out:
#                                   titles  similarity
# 0                  lighting up the stars    1.000000
# 1                                   papa    0.596285
# 2                          salut d'amour    0.596285
# 3                           dad for rent    0.596285
# 4                      moratorium tamako    0.547723
# 5                                   step    0.527046
# 6                    an autumn afternoon    0.516398
# 7             sori: voice from the heart    0.516398
# 8                          oi handsome!!    0.516398
# 9                      a day with my son    0.516398
# 10                             a bedsore    0.489898
# 11                         still walking    0.484544
# 12                   christmas in august    0.456435
# 13             my dad is a heel wrestler    0.447214
# 14                         gunkan shonen    0.447214
# 15                  the shadowless tower    0.447214
# 16                        meet mr. daddy    0.447214
# 17  how the lack of love affects two men    0.447214
# 18                               to live    0.440386
# 19                       seoul searching    0.438357

# %%
get_recommendation_bytag('lighting up the stars')
# Out:
#                        titles  similarity
# 0       lighting up the stars    1.000000
# 1                        papa    0.454605
# 2                dad for rent    0.451531
# 3           moratorium tamako    0.409701
# 4               oi handsome!!    0.408133
# 5           a day with my son    0.395068
# 6  sori: voice from the heart    0.387922
# 7               salut d'amour    0.369134
# 8        the shadowless tower    0.365321
# 9               gunkan shonen    0.356489

# %% [markdown]
# #### RECOMMENDATION USING MOVIE DESCRIPTION

# %%
tv = CountVectorizer(stop_words= 'english')
transformed = tv.fit_transform(cleaned_series)
cos = cosine_similarity(transformed, transformed)

# %%
tv = TfidfVectorizer(stop_words='english')
transformed = tv.fit_transform(cleaned_series)
cos = linear_kernel(transformed, transformed)

# %%
CountVectorizer()

# %%
transformed.shape
# Out:
# (4970, 21713)

# %%
reversed = pd.Series(df.index, index= df['titles'])

# %%
reversed[reversed== 2709]
# Out:
# titles
# monster    2709
# dtype: int64

# %%
#idx = reversed[title]
cos_score = list(enumerate(cos[2709]))
cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
first_10 = cos_score[0:10]
rec_indices = [x[0] for x in first_10]
rec_sim = [x[1] for x in first_10]
soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
hot = pd.Series(rec_sim).to_frame()
dff = pd.concat((soft, hot), axis= 1)
dff.columns=['titles', 'similarity']
dff
# Out:
#                  titles  similarity
# 0               monster    1.000000
# 1              silenced    0.226271
# 2  shichinin no tomurai    0.170784
# 3             lost love    0.152134
# 4      school excursion    0.143379
# 5    sansho the bailiff    0.140129
# 6               at home    0.134022
# 7          tokyo family    0.129332
# 8        kuchisake onna    0.117565
# 9         birthday card    0.116847

# %%
def get_recommendation(title, cos =  cos):
    idx = reversed[title]
    cos_score = list(enumerate(cos[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
get_recommendation('confidential assignment')
# Out:
#                                       titles  similarity
# 0                    confidential assignment    1.000000
# 1                        joint security area    0.307776
# 2   confidential assignment 2: international    0.272549
# 3                                 steel rain    0.258217
# 4                                       6/45    0.254622
# 5                                    the net    0.239689
# 6                    children gone to poland    0.233145
# 7                                   poongsan    0.224492
# 8                             secret reunion    0.222408
# 9                             beautiful days    0.220903
# 10                                   veteran    0.218855
# 11                         the long way home    0.218801
# 12                        the spy gone north    0.214668
# 13                           hello, stranger    0.201801
# 14                           ordinary people    0.199653
# 15                           city of fathers    0.188113
# 16                            dear pyongyang    0.170360
# 17        tae guk gi: the brotherhood of war    0.169535
# 18                        i, the executioner    0.169251
# 19                          romantic debtors    0.168742

# %%
get_recommendation_bytag('confidential assignment')
# Out:
#                                      titles  similarity
# 0                   confidential assignment    1.000000
# 1  confidential assignment 2: international    0.600000
# 2                          secretly greatly    0.400000
# 3                                    carter    0.381385
# 4                        operation chromite    0.300000
# 5                                the prison    0.300000
# 6       the gangster, the cop and the devil    0.300000
# 7     the accidental detective 2: in action    0.300000
# 8    dragon inn part 1: the city of sadness    0.300000
# 9                          masquerade night    0.300000

# %%
get_recommendation('exhuma')
# Out:
#                                                titles  similarity
# 0                                              exhuma    1.000000
# 1                                       the concubine    0.180253
# 2                                     rules of dating    0.173399
# 3                                     a frozen flower    0.144851
# 4                                hwayi: a monster boy    0.143215
# 5                                   citizen of a kind    0.139662
# 6                                       dancing queen    0.139147
# 7                                          man wanted    0.133890
# 8                                      perfect number    0.128801
# 9             along with the gods 2: the last 49 days    0.127768
# 10                                south of the border    0.125744
# 11                                             jigoku    0.120599
# 12                                   begging for love    0.117997
# 13                                five senses of eros    0.115314
# 14                                   don't cry, mommy    0.111036
# 15                                 when i turned nine    0.107395
# 16                               fantasy of the girls    0.103663
# 17                                         first kiss    0.103142
# 18                                      hello my love    0.100136
# 19  kaizoku sentai goukaiger vs. space sheriff gav...    0.098979

# %%
get_recommendation_bytag('exhuma')
# Out:
#                                       titles  similarity
# 0                                     exhuma    1.000000
# 1                dr. cheon and lost talisman    0.381385
# 2                            karaoke crazies    0.316228
# 3                            qin zei you dao    0.316228
# 4                            address unknown    0.316228
# 5             the secret of the black dahlia    0.316228
# 6            jenius: countdown in the riddle    0.316228
# 7               monster emperor: extra story    0.316228
# 8                the cursed: dead man's prey    0.316228
# 9                    while you were sleeping    0.316228
# 10  bayside shakedown 3: set the guys loose!    0.316228
# 11                           the missing gun    0.316228
# 12                        love and treachery    0.316228
# 13                                     trunk    0.316228
# 14                            love in summer    0.316228
# 15                                 onmyoji 0    0.282843
# 16               trick the movie: last stage    0.239046
# 17                     the butterfly murders    0.223607
# 18        the adventures of kosuke kindaichi    0.223607
# 19                                   bad cop    0.223607

# %%
get_recommendation_bycast('exhuma')
# Out:
#                          titles  similarity
# 0                        exhuma    1.000000
# 1                 swimming bird    0.235702
# 2      tazza 2: the hidden card    0.182574
# 3              the quiet family    0.166667
# 4                         shiri    0.166667
# 5                     happy end    0.166667
# 6              our twisted hero    0.166667
# 7                 a taxi driver    0.166667
# 8      1987: when the day comes    0.166667
# 9                        canola    0.166667
# 10      confidential assignment    0.166667
# 11                     luck-key    0.166667
# 12              heart blackened    0.166667
# 13                     old days    0.166667
# 14   malmoe: the secret mission    0.166667
# 15             tune in for love    0.166667
# 16  the battle: roar to victory    0.166667
# 17        sunset in my hometown    0.166667
# 18           intimate strangers    0.166667
# 19              forbidden dream    0.166667

# %%
get_recommendation_bygenre('exhuma')
# Out:
#                                   titles  similarity
# 0   whispering corridors 2: memento mori         1.0
# 1                   whispering corridors         1.0
# 2                            the wailing         1.0
# 3               house of the disappeared         1.0
# 4                              the mimic         1.0
# 5                    hide and never seek         1.0
# 6                gonjiam: haunted asylum         1.0
# 7                             the closet         1.0
# 8                svaha: the sixth finger         1.0
# 9                                deja vu         1.0
# 10           the cursed: dead man's prey         1.0
# 11                             re/member         1.0
# 12                 the grotesque mansion         1.0
# 13                         the 8th night         1.0
# 14                       rohan au louvre         1.0
# 15                        the haunting 2         1.0
# 16                        the haunting 3         1.0
# 17                                exhuma         1.0
# 18                 a tale of two sisters         1.0
# 19                               the eye         1.0

# %% [markdown]
# ##### MOVIE RECOMMENDATION BY CAST

# %%
cast = df['cast']

# %%
cast = cast.fillna('nocast')

# %%
cast = cast.str.strip()
cast = cast.str.replace(' ', '')
cast = cast.str.lower()

# %%
cs = CountVectorizer()
cast_transformed  = cs.fit_transform(cast)
cast_sim = cosine_similarity(cast_transformed, cast_transformed)

# %%
def get_recommendation_bycast(title, cast_sim = cast_sim):
    idx = reversed[title]
    cos_score = list(enumerate(cast_sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
genre =  df['genres']

# %%
genre = genre.fillna('no genre')
genre = genre.str.strip()
genre = genre.str.replace(' ', '')
genre = genre.str.lower()

# %%
gn = TfidfVectorizer()
genre_transformed = gn.fit_transform(genre)
genre_sim = linear_kernel(genre_transformed, genre_transformed)

# %%
def get_recommendation_bygenre(title, genre_sim = genre_sim):
    idx = reversed[title]
    cos_score = list(enumerate(genre_sim[idx]))
    cos_score = sorted(cos_score, key=lambda x:x[1], reverse=True)
    first_10 = cos_score[0:20]
    rec_indices = [x[0] for x in first_10]
    rec_sim = [x[1] for x in first_10]
    soft = pd.Series(list(df['titles'].iloc[rec_indices])).to_frame()
    hot = pd.Series(rec_sim).to_frame()
    dff = pd.concat((soft, hot), axis= 1)
    dff.columns=['titles', 'similarity']
    return dff

# %%
pd.DataFrame(cos, index=df["titles"], columns=df["titles"])
# Out:
# titles                                             Hachiko Monogatari  \
# titles
# Hachiko Monogatari                                           1.000000
# Seven Samurai                                                0.045805
# Harakiri                                                     0.017396
# Ikiru                                                        0.046219
# Ran                                                          0.067311
# ...                                                               ...
# The Furthest End Awaits                                      0.027137
# Contact Point                                                0.048913
# Isao Takahata and His Tale of the Princess Kaguya            0.037213
# Beautiful Legacy                                             0.030843
# Orpheus' Lyre                                                0.030221
#
# titles                                             Seven Samurai  Harakiri  \
# titles
# Hachiko Monogatari                                      0.045805  0.017396
# Seven Samurai                                           1.000000  0.138600
# Harakiri                                                0.138600  1.000000
# Ikiru                                                   0.048601  0.025758
# Ran                                                     0.073598  0.121041
# ...                                                          ...       ...
# The Furthest End Awaits                                 0.017961  0.012734
# Contact Point                                           0.040397  0.024501
# Isao Takahata and His Tale of the Princess Kaguya       0.052027  0.011122
# Beautiful Legacy                                        0.028294  0.006333
# Orpheus' Lyre                                           0.030696  0.053304
#
# titles                                               Ikiru        Ran  \
# titles
# Hachiko Monogatari                                 0.046219  0.067311
# Seven Samurai                                      0.048601  0.073598
# Harakiri                                           0.025758  0.121041
# Ikiru                                              1.000000  0.103619
# Ran                                                0.103619  1.000000
# ...                                                     ...       ...
# The Furthest End Awaits                            0.025637  0.023800
# Contact Point                                      0.082942  0.074867
# Isao Takahata and His Tale of the Princess Kaguya  0.039096  0.073603
# Beautiful Legacy                                   0.118343  0.089930
# Orpheus' Lyre                                      0.047000  0.043425
#
# titles                                              Yojimbo  Rashomon  \
# titles
# Hachiko Monogatari                                 0.049357  0.063321
# Seven Samurai                                      0.126092  0.172681
# Harakiri                                           0.084405  0.111894
# Ikiru                                              0.070524  0.069839
# Ran                                                0.135995  0.109307
# ...                                                     ...       ...
# The Furthest End Awaits                            0.025593  0.029961
# Contact Point                                      0.051393  0.046685
# Isao Takahata and His Tale of the Princess Kaguya  0.055287  0.063333
# Beautiful Legacy                                   0.056234  0.044698
# Orpheus' Lyre                                      0.053805  0.055070
#
# titles                                             Tokyo Story   \
# titles
# Hachiko Monogatari                                     0.040410
# Seven Samurai                                          0.055109
# Harakiri                                               0.024200
# Ikiru                                                  0.080100
# Ran                                                    0.088009
# ...                                                         ...
# The Furthest End Awaits                                0.064684
# Contact Point                                          0.083352
# Isao Takahata and His Tale of the Princess Kaguya      0.041400
# Beautiful Legacy                                       0.034237
# Orpheus' Lyre                                          0.062247
#
# titles                                             High and Low   \
# titles
# Hachiko Monogatari                                      0.046976
# Seven Samurai                                           0.057117
# Harakiri                                                0.038766
# Ikiru                                                   0.062083
# Ran                                                     0.109200
# ...                                                          ...
# The Furthest End Awaits                                 0.015026
# Contact Point                                           0.029385
# Isao Takahata and His Tale of the Princess Kaguya       0.042655
# Beautiful Legacy                                        0.032226
# Orpheus' Lyre                                           0.035502
#
# titles                                             The Last Emperor  ...  \
# titles                                                               ...
# Hachiko Monogatari                                         0.065561  ...
# Seven Samurai                                              0.066964  ...
# Harakiri                                                   0.010359  ...
# Ikiru                                                      0.047353  ...
# Ran                                                        0.092432  ...
# ...                                                             ...  ...
# The Furthest End Awaits                                    0.013153  ...
# Contact Point                                              0.053638  ...
# Isao Takahata and His Tale of the Princess Kaguya          0.058414  ...
# Beautiful Legacy                                           0.051030  ...
# Orpheus' Lyre                                              0.037334  ...
#
# titles                                             Carrying Spring  \
# titles
# Hachiko Monogatari                                        0.043918
# Seven Samurai                                             0.045504
# Harakiri                                                  0.011707
# Ikiru                                                     0.055290
# Ran                                                       0.100245
# ...                                                            ...
# The Furthest End Awaits                                   0.038191
# Contact Point                                             0.043611
# Isao Takahata and His Tale of the Princess Kaguya         0.057240
# Beautiful Legacy                                          0.106955
# Orpheus' Lyre                                             0.040530
#
# titles                                             Goodbye Debussy  \
# titles
# Hachiko Monogatari                                        0.024671
# Seven Samurai                                             0.040589
# Harakiri                                                  0.023871
# Ikiru                                                     0.030251
# Ran                                                       0.046813
# ...                                                            ...
# The Furthest End Awaits                                   0.049328
# Contact Point                                             0.031471
# Isao Takahata and His Tale of the Princess Kaguya         0.027175
# Beautiful Legacy                                          0.029757
# Orpheus' Lyre                                             0.065846
#
# titles                                             12th Assistant Deacon  \
# titles
# Hachiko Monogatari                                              0.029749
# Seven Samurai                                                   0.039290
# Harakiri                                                        0.010240
# Ikiru                                                           0.018447
# Ran                                                             0.043963
# ...                                                                  ...
# The Furthest End Awaits                                         0.016372
# Contact Point                                                   0.023003
# Isao Takahata and His Tale of the Princess Kaguya               0.030702
# Beautiful Legacy                                                0.020410
# Orpheus' Lyre                                                   0.022664
#
# titles                                             Phone Call to the Bar 2  \
# titles
# Hachiko Monogatari                                                0.024575
# Seven Samurai                                                     0.030824
# Harakiri                                                          0.020137
# Ikiru                                                             0.033627
# Ran                                                               0.050368
# ...                                                                    ...
# The Furthest End Awaits                                           0.023984
# Contact Point                                                     0.037404
# Isao Takahata and His Tale of the Princess Kaguya                 0.033131
# Beautiful Legacy                                                  0.024449
# Orpheus' Lyre                                                     0.027058
#
# titles                                             MAD SAD BAD  \
# titles
# Hachiko Monogatari                                    0.036342
# Seven Samurai                                         0.048732
# Harakiri                                              0.025015
# Ikiru                                                 0.059330
# Ran                                                   0.048950
# ...                                                        ...
# The Furthest End Awaits                               0.044155
# Contact Point                                         0.035113
# Isao Takahata and His Tale of the Princess Kaguya     0.031143
# Beautiful Legacy                                      0.113270
# Orpheus' Lyre                                         0.046232
#
# titles                                             The Furthest End Awaits  \
# titles
# Hachiko Monogatari                                                0.027137
# Seven Samurai                                                     0.017961
# Harakiri                                                          0.012734
# Ikiru                                                             0.025637
# Ran                                                               0.023800
# ...                                                                    ...
# The Furthest End Awaits                                           1.000000
# Contact Point                                                     0.042546
# Isao Takahata and His Tale of the Princess Kaguya                 0.018996
# Beautiful Legacy                                                  0.036760
# Orpheus' Lyre                                                     0.060140
#
# titles                                             Contact Point  \
# titles
# Hachiko Monogatari                                      0.048913
# Seven Samurai                                           0.040397
# Harakiri                                                0.024501
# Ikiru                                                   0.082942
# Ran                                                     0.074867
# ...                                                          ...
# The Furthest End Awaits                                 0.042546
# Contact Point                                           1.000000
# Isao Takahata and His Tale of the Princess Kaguya       0.045415
# Beautiful Legacy                                        0.042912
# Orpheus' Lyre                                           0.077162
#
# titles                                             Isao Takahata and His Tale of the Princess Kaguya  \
# titles
# Hachiko Monogatari                                                                          0.037213
# Seven Samurai                                                                               0.052027
# Harakiri                                                                                    0.011122
# Ikiru                                                                                       0.039096
# Ran                                                                                         0.073603
# ...                                                                                              ...
# The Furthest End Awaits                                                                     0.018996
# Contact Point                                                                               0.045415
# Isao Takahata and His Tale of the Princess Kaguya                                           1.000000
# Beautiful Legacy                                                                            0.035827
# Orpheus' Lyre                                                                               0.026510
#
# titles                                             Beautiful Legacy  \
# titles
# Hachiko Monogatari                                         0.030843
# Seven Samurai                                              0.028294
# Harakiri                                                   0.006333
# Ikiru                                                      0.118343
# Ran                                                        0.089930
# ...                                                             ...
# The Furthest End Awaits                                    0.036760
# Contact Point                                              0.042912
# Isao Takahata and His Tale of the Princess Kaguya          0.035827
# Beautiful Legacy                                           1.000000
# Orpheus' Lyre                                              0.047170
#
# titles                                             Orpheus' Lyre
# titles
# Hachiko Monogatari                                      0.030221
# Seven Samurai                                           0.030696
# Harakiri                                                0.053304
# Ikiru                                                   0.047000
# Ran                                                     0.043425
# ...                                                          ...
# The Furthest End Awaits                                 0.060140
# Contact Point                                           0.077162
# Isao Takahata and His Tale of the Princess Kaguya       0.026510
# Beautiful Legacy                                        0.047170
# Orpheus' Lyre                                           1.000000
#
# [4970 rows x 4970 columns]
